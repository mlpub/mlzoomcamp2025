# %% [markdown]
# ## 2. Machine Learning for Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
# Load the data into a DataFrame
df = pd.read_csv(data)

# %%
df.head(3)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
#
#    highway MPG  city mpg  Popularity   MSRP
# 0           26        19        3916  46135
# 1           28        19        3916  40650
# 2           28        20        3916  36350

# %% [markdown]
# ### Split and shuffle data

# %% [markdown]
# Data need to shuffle and split for training, validation and test.
#
# Why it need to shuffle?
#
# If the dataset is sorted by some feature (for example, make, year, region, or time), then simply taking the first 60% for training and the rest for validation/test will not represent the whole population.
# Example, the dataset is sorted by make, the training data will like ['bmw','bmw',...,'ford',..., 'toyota',...].
#
# If we take the first 60% as the training set, it will mostly contain BMW and Ford.
# The validation set may contain mostly Toyota.
#
# As a result, the model will learn well for BMW and Ford but will perform poorly on Toyota, because it never saw enough Toyota samples during training.
#
# Shuffling makes the data well-mixed, so each subset (training, validation, and test) has a similar distribution of all makes.
#
# For time-series data (like stock, electricity consumption), we should not shuffle, because the data has a natural order.

# %%
# get length of dataframe
n = len(df)
print(n)
# Out:
# 11914

# %%
# generate array sequence from 0 to n-1
idx = np.arange(n)
print(idx)
# Out:
# [    0     1     2 ... 11911 11912 11913]

# %%
# shuffle the array idx`
# use a random seed to make the shuffling reproducible
np.random.seed(2)
np.random.shuffle(idx)

print(idx)
# Out:
# [2735 6720 5878 ... 6637 2575 7336]

# %%
# split the data into train, val, test. 60% train, 20% val, 20% test
n_test = int(n * 0.2)
n_val = int(n * 0.2)
n_train = n - n_val - n_test

print(n_train, n_val, n_test)
# Out:
# 7150 2382 2382

# %%
# split the df into train, val, test using the idx array

# df_train = idx 0..n_train
df_train = df.iloc[idx[:n_train]]

# df_val = idx n_train..n_train+n_val
df_val = df.iloc[idx[n_train:n_train + n_val]]

# df_test = idx n_train+n_val..end
df_test = df.iloc[idx[n_train + n_val:]]

print(len(df_train), len(df_val), len(df_test))
# Out:
# 7150 2382 2382

# %%
# preview df_train
df_train.head(10)
# Out:
#              Make            Model  Year             Engine Fuel Type  \
# 2735    Chevrolet           Cobalt  2008             regular unleaded
# 6720       Toyota           Matrix  2012             regular unleaded
# 5878       Subaru          Impreza  2016             regular unleaded
# 11190  Volkswagen          Vanagon  1991             regular unleaded
# 4554         Ford            F-150  2017     flex-fuel (unleaded/E85)
# 8001   Volkswagen           Rabbit  2008             regular unleaded
# 2882      Bentley  Continental GTC  2013  premium unleaded (required)
# 649           BMW         6 Series  2015  premium unleaded (required)
# 616       Maybach               57  2012  premium unleaded (required)
# 4459         Ford   F-150 Heritage  2004             regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 2735       148.0               4.0            MANUAL  front wheel drive
# 6720       132.0               4.0         AUTOMATIC  front wheel drive
# 5878       148.0               4.0         AUTOMATIC    all wheel drive
# 11190       90.0               4.0            MANUAL   rear wheel drive
# 4554       385.0               8.0         AUTOMATIC   four wheel drive
# 8001       170.0               5.0            MANUAL  front wheel drive
# 2882       500.0               8.0         AUTOMATIC    all wheel drive
# 649        315.0               6.0         AUTOMATIC   rear wheel drive
# 616        543.0              12.0         AUTOMATIC   rear wheel drive
# 4459       202.0               6.0            MANUAL   four wheel drive
#
#        Number of Doors                 Market Category Vehicle Size  \
# 2735               2.0                             NaN      Compact
# 6720               4.0                       Hatchback      Compact
# 5878               4.0                       Hatchback      Compact
# 11190              3.0                             NaN        Large
# 4554               4.0                       Flex Fuel        Large
# 8001               4.0                       Hatchback      Compact
# 2882               2.0  Exotic,Luxury,High-Performance      Midsize
# 649                2.0              Luxury,Performance      Midsize
# 616                4.0                   Exotic,Luxury        Large
# 4459               2.0                             NaN        Large
#
#             Vehicle Style  highway MPG  city mpg  Popularity    MSRP
# 2735                Coupe           33        24        1385   14410
# 6720        4dr Hatchback           32        25        2031   19685
# 5878        4dr Hatchback           37        28         640   19795
# 11190   Passenger Minivan           18        16         873    2000
# 4554      Crew Cab Pickup           21        15        5657   56260
# 8001        4dr Hatchback           29        22         873   17575
# 2882          Convertible           24        14         520  191400
# 649                 Coupe           32        21        3916   76100
# 616                 Sedan           16        10          67  379050
# 4459   Regular Cab Pickup           18        13        5657   26030

# %%
# preview df_val
df_val.head(10)
# Out:
#                 Make               Model  Year  \
# 2779       Chevrolet            Colorado  2015
# 3708   Mercedes-Benz             E-Class  2017
# 4794            Ford               Focus  2017
# 10498          Acura                 TLX  2016
# 1880      Volkswagen  Beetle Convertible  2016
# 7587          Toyota              Pickup  1995
# 7035          Nissan              Murano  2016
# 892             Saab                 900  1996
# 4911      Land Rover          Freelander  2004
# 10011          Dodge             Stratus  2004
#
#                      Engine Fuel Type  Engine HP  Engine Cylinders  \
# 2779                 regular unleaded      200.0               4.0
# 3708      premium unleaded (required)      241.0               4.0
# 4794         flex-fuel (unleaded/E85)      160.0               4.0
# 10498  premium unleaded (recommended)      290.0               6.0
# 1880                 regular unleaded      170.0               4.0
# 7587                 regular unleaded      116.0               4.0
# 7035                 regular unleaded      260.0               6.0
# 892                  regular unleaded      185.0               4.0
# 4911                 regular unleaded      174.0               6.0
# 10011                regular unleaded      200.0               6.0
#
#       Transmission Type      Driven_Wheels  Number of Doors  \
# 2779          AUTOMATIC   four wheel drive              4.0
# 3708          AUTOMATIC    all wheel drive              4.0
# 4794             MANUAL  front wheel drive              4.0
# 10498         AUTOMATIC  front wheel drive              4.0
# 1880          AUTOMATIC  front wheel drive              2.0
# 7587             MANUAL   rear wheel drive              2.0
# 7035          AUTOMATIC    all wheel drive              4.0
# 892              MANUAL  front wheel drive              2.0
# 4911          AUTOMATIC    all wheel drive              4.0
# 10011            MANUAL  front wheel drive              4.0
#
#           Market Category Vehicle Size        Vehicle Style  highway MPG  \
# 2779                  NaN      Compact  Extended Cab Pickup           25
# 3708               Luxury      Midsize                Sedan           29
# 4794            Flex Fuel      Compact                Sedan           36
# 10498              Luxury      Midsize                Sedan           34
# 1880                  NaN      Compact          Convertible           34
# 7587                  NaN      Compact   Regular Cab Pickup           25
# 7035            Crossover      Midsize              4dr SUV           28
# 892    Luxury,Performance      Compact          Convertible           26
# 4911     Crossover,Luxury      Compact              4dr SUV           19
# 10011         Performance      Midsize                Sedan           25
#
#        city mpg  Popularity   MSRP
# 2779         19        1385  26885
# 3708         22         617  54650
# 4794         26        5657  16775
# 10498        21         204  42600
# 1880         25         873  25995
# 7587         19        2031   2000
# 7035         21        2009  34400
# 892          18         376   2000
# 4911         16         258  25330
# 10011        17        1851  22370

# %%
# preview df_test
df_test.head(10)
# Out:
#                 Make           Model  Year                Engine Fuel Type  \
# 11195            GMC         Vandura  1994                regular unleaded
# 673    Mercedes-Benz       600-Class  1993                regular unleaded
# 11270         Toyota           Venza  2013                regular unleaded
# 752            Volvo             740  1992                regular unleaded
# 3137            Ford  Crown Victoria  2010        flex-fuel (unleaded/E85)
# 1027            Audi              A3  2015  premium unleaded (recommended)
# 8133           Dodge       Ram Cargo  2002                regular unleaded
# 10823          Mazda         Tribute  2011                regular unleaded
# 3018       Chevrolet        Corvette  2017  premium unleaded (recommended)
# 8994         Hyundai        Santa Fe  2016                regular unleaded
#
#        Engine HP  Engine Cylinders Transmission Type      Driven_Wheels  \
# 11195      165.0               6.0         AUTOMATIC   rear wheel drive
# 673        389.0              12.0         AUTOMATIC   rear wheel drive
# 11270      268.0               6.0         AUTOMATIC    all wheel drive
# 752        114.0               4.0         AUTOMATIC   rear wheel drive
# 3137       224.0               8.0         AUTOMATIC   rear wheel drive
# 1027       220.0               4.0  AUTOMATED_MANUAL    all wheel drive
# 8133       175.0               6.0         AUTOMATIC   rear wheel drive
# 10823      171.0               4.0         AUTOMATIC    all wheel drive
# 3018       460.0               8.0            MANUAL   rear wheel drive
# 8994       290.0               6.0         AUTOMATIC  front wheel drive
#
#        Number of Doors        Market Category Vehicle Size Vehicle Style  \
# 11195              3.0                    NaN      Compact     Cargo Van
# 673                2.0                 Luxury        Large         Coupe
# 11270              4.0  Crossover,Performance      Midsize         Wagon
# 752                4.0                 Luxury      Midsize         Sedan
# 3137               4.0              Flex Fuel        Large         Sedan
# 1027               2.0                 Luxury      Compact   Convertible
# 8133               3.0                    NaN      Compact     Cargo Van
# 10823              4.0              Crossover      Compact       4dr SUV
# 3018               2.0       High-Performance      Compact   Convertible
# 8994               4.0              Crossover      Midsize       4dr SUV
#
#        highway MPG  city mpg  Popularity   MSRP
# 11195           20        15         549   2000
# 673             15        11         617   3211
# 11270           25        18        2031  31120
# 752             26        18         870   2000
# 3137            24        16        5657  29905
# 1027            32        23        3105  41150
# 8133            15        13        1851  19275
# 10823           26        20         586  25495
# 3018            25        16        1385  69450
# 8994            25        18        1439  34500
